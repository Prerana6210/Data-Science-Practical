# %% [markdown]
# <a href="https://colab.research.google.com/github/Prerana6210/Data-Science-Practical/blob/main/Practical_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_excel("/content/Book1.xlsx")
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-693af6e91327> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data=pd.read_excel("/content/Book1.xlsx")
#       3 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("/content/cat.jpg")
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-70-671fe84784a8> in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import matplotlib.image as mpimg
# ----> 3 img = mpimg.imread("/content/cat.jpg")
#       4 plt.imshow(img)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in imread(fname, format)
#    1561             "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562             )
# -> 1563     with img_open(fname) as image:
#    1564         return (_pil_png_to_float_array(image)
#    1565                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# ...

# %% [markdown]
# summarizing data with statistics

# %%
import pandas as pd
df=pd.DataFrame({"Sr.no":[1,1,3,4,5],"Rollno":[6201,6201,6203,6204,6205],"Name":["mansi","mansi","ananya","lavanya","anvisha"],"Class":['A','B','A','B','A'],"Marks":[55,85,25,15,31]})
df
# Out:
#    Sr.no  Rollno     Name Class  Marks
# 0      1    6201    mansi     A     55
# 1      1    6201    mansi     B     85
# 2      3    6203   ananya     A     25
# 3      4    6204  lavanya     B     15
# 4      5    6205  anvisha     A     31

# %%
df.isnull().sum()
# Out:
# Sr.no     0
# Rollno    0
# Name      0
# Class     0
# Marks     0
# dtype: int64

# %%
df.value_counts()
# Out:
# Sr.no  Rollno  Name     Class  Marks
# 1      6201    mansi    A      55       1
#                         B      85       1
# 3      6203    ananya   A      25       1
# 4      6204    lavanya  B      15       1
# 5      6205    anvisha  A      31       1
# dtype: int64

# %%
df.describe()
# Out:
#           Sr.no       Rollno      Marks
# count  5.000000     5.000000   5.000000
# mean   2.800000  6202.800000  42.200000
# std    1.788854     1.788854  28.092704
# min    1.000000  6201.000000  15.000000
# 25%    1.000000  6201.000000  25.000000
# 50%    3.000000  6203.000000  31.000000
# 75%    4.000000  6204.000000  55.000000
# max    5.000000  6205.000000  85.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sr.no   5 non-null      int64
#  1   Rollno  5 non-null      int64
#  2   Name    5 non-null      object
#  3   Class   5 non-null      object
#  4   Marks   5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
df.describe(include="object")
# Out:
#          Name Class
# count       5     5
# unique      4     2
# top     mansi     A
# freq        2     3

# %%
df.nunique()
# Out:
# Sr.no     4
# Rollno    4
# Name      4
# Class     2
# Marks     5
# dtype: int64

# %%
df.duplicated().sum()

# %%
df.duplicated(['Name']).sum()
# Out:
# 1

# %%
df.nunique()

# %%
df['Name'].value_counts()
# Out:
# mansi      2
# ananya     1
# lavanya    1
# anvisha    1
# Name: Name, dtype: int64

# %%
df['Class'].nunique()
# Out:
# 2

# %%
df['Class'].value_counts()
# Out:
# A    3
# B    2
# Name: Class, dtype: int64

# %%
df['Marks'].mean()
# Out:
# 42.2

# %%
df['Marks'].var()
# Out:
# 789.1999999999999

# %%
correlation=df.corr()
correlation
# Out:
# <ipython-input-95-edac34d0c35e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=df.corr()
#           Sr.no   Rollno    Marks
# Sr.no   1.00000  1.00000 -0.79994
# Rollno  1.00000  1.00000 -0.79994
# Marks  -0.79994 -0.79994  1.00000

# %%
import seaborn as sns
sns.heatmap(correlation,annot=True,fmt='.2f',cmap='crest')
# Out:
# <Axes: >
